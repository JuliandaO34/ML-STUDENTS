# %% [markdown]
# <a href="https://colab.research.google.com/github/JuliandaO34/ML-STUDENTS/blob/main/Proyecto_bootcamp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Carga un archivo CSV y revisa las primeras filas y su estructura general con `head()` e `info()` para asegurar que fue leído correctamente.

import pandas as pd

# Assuming your CSV file is named 'your_file.csv'
# Replace 'your_file.csv' with the actual name of your file
try:
  df = pd.read_csv('DATASTUDENTS.csv', sep=";")
  print("Primeras filas del DataFrame:")
  print("\nInformación general del DataFrame:")
  df.info()
except FileNotFoundError:
  print("Error: ''DATASTUDENTS.csv'' no encontrado. Asegúrate de que el archivo CSV está en el directorio correcto.")
except Exception as e:
  print(f"Ocurrió un error al leer el archivo CSV: {e}")
  print(df.head())
# Out:
# Primeras filas del DataFrame:
#
# Información general del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
# ...

# %%
df.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous qualification (grade)  Nacionality  Mothers qualification  \
# 0                           122.0            1                     19
# 1                           160.0            1                      1
# ...

# %%
# cuantas filas tiene el dataframe

print(f"El dataframe tiene {len(df)} filas.")
# Out:
# El dataframe tiene 4424 filas.

# %%
# Eliminar las columnas "Marital Status"
columns_to_drop = ["Marital status"]
df = df.drop(columns=columns_to_drop, errors='ignore')

print("\nDataFrame después de eliminar columnas:")
print(df.head())
# Out:
# DataFrame después de eliminar columnas:
#    Application mode  Application order  Course  Daytime/evening attendance  \
# 0                17                  5     171                           1
# 1                15                  1    9254                           1
# 2                 1                  5    9070                           1
# 3                17                  2    9773                           1
# 4                39                  1    8014                           0
#
#    Previous qualification  Previous qualification (grade)  Nacionality  \
# 0                       1                           122.0            1
# 1                       1                           160.0            1
# 2                       1                           122.0            1
# 3                       1                           122.0            1
# 4                       1                           100.0            1
#
# ...

# %%
df.head()
# Out:
#    Application mode  Application order  Course  Daytime/evening attendance  \
# 0                17                  5     171                           1
# 1                15                  1    9254                           1
# 2                 1                  5    9070                           1
# 3                17                  2    9773                           1
# 4                39                  1    8014                           0
#
#    Previous qualification  Previous qualification (grade)  Nacionality  \
# 0                       1                           122.0            1
# 1                       1                           160.0            1
# 2                       1                           122.0            1
# 3                       1                           122.0            1
# 4                       1                           100.0            1
#
#    Mothers qualification  Fathers qualification  Mothers occupation  ...  \
# ...

# %%
# Crea dos listas separadas con los nombres de las variables numéricas y categóricas para tratarlas de forma diferenciada en el análisis.
# Permíteme definir algunas que son categóricas pero que están en el dataset como numéricas nominales

# Lista de variables que son categóricas pero están representadas como numéricas
categorical_numerical_vars = ['Gender', 'Daytime/evening attendance','Displaced', 'Educational special needs', 'Debtor', 'Tuition fees up to date', 'Scholarship holder', 'International', 'Application mode', 'Application order', 'Course', 'Previous qualification', 'Previous qualification (grade)', 'Nacionality', 'Mothers qualification', 'Fathers qualification', 'Mothers occupation', 'Fathers occupation', 'Admission grade', 'Target'] # Agrega aquí los nombres de tus variables

# Separar las columnas en listas de variables numéricas y categóricas
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()

# Mover las variables especificadas de la lista numérica a la categórica si existen en la lista numérica
for var in categorical_numerical_vars:
    if var in numeric_cols:
        numeric_cols.remove(var)
        categorical_cols.append(var)

print("Variables numéricas:", numeric_cols)
print("Variables categóricas:", categorical_cols)
# Out:
# Variables numéricas: ['Age at enrollment', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (enrolled)', 'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (approved)', 'Curricular units 1st sem (grade)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (enrolled)', 'Curricular units 2nd sem (evaluations)', 'Curricular units 2nd sem (approved)', 'Curricular units 2nd sem (grade)', 'Curricular units 2nd sem (without evaluations)', 'Unemployment rate', 'Inflation rate', 'GDP']
# ...

# %%
# Revisa si hay valores nulos por columna usando `isnull().sum()` y eliminarlos

# Verificar si hay valores nulos por columna
print("Número de valores nulos por columna antes de la eliminación:")
print(df.isnull().sum())

# Eliminar filas con cualquier valor nulo
df.dropna(inplace=True)

print("\nDataFrame después de eliminar filas con valores nulos:")
print(df.head())

print("\nNúmero de valores nulos por columna después de la eliminación:")
print(df.isnull().sum())
# Out:
# Número de valores nulos por columna antes de la eliminación:
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mothers qualification                             0
# Fathers qualification                             0
# Mothers occupation                                0
# Fathers occupation                                0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# ...

# %%
#  Convierte las columnas categóricas  que corresponden a en números usando LabelEncoder

from sklearn.preprocessing import LabelEncoder

# Inicializar LabelEncoder
label_encoder = LabelEncoder()

# Aplicar LabelEncoder a cada columna categórica
for col in categorical_cols:
    df[col] = label_encoder.fit_transform(df[col])

print("\nDataFrame después de la codificación con LabelEncoder:")
print(df.head())

# Verificar los tipos de datos después de la codificación
print("\nTipos de datos después de la codificación:")
df.dtypes
# Out:
# DataFrame después de la codificación con LabelEncoder:
#    Application mode  Application order  Course  Daytime/evening attendance  \
# 0                 7                  5       1                           1
# 1                 5                  1      10                           1
# 2                 0                  5       4                           1
# 3                 7                  2      14                           1
# 4                11                  1       2                           0
#
#    Previous qualification  Previous qualification (grade)  Nacionality  \
# 0                       0                              28            0
# 1                       0                              78            0
# 2                       0                              28            0
# 3                       0                              28            0
# 4                       0                               4            0
#
# ...

# %%
df.head()
# Out:
#    Application mode  Application order  Course  Daytime/evening attendance  \
# 0                 7                  5       1                           1
# 1                 5                  1      10                           1
# 2                 0                  5       4                           1
# 3                 7                  2      14                           1
# 4                11                  1       2                           0
#
#    Previous qualification  Previous qualification (grade)  Nacionality  \
# 0                       0                              28            0
# 1                       0                              78            0
# 2                       0                              28            0
# 3                       0                              28            0
# 4                       0                               4            0
#
#    Mothers qualification  Fathers qualification  Mothers occupation  ...  \
# ...

# %%
df.describe()
# Out:
#        Application mode  Application order       Course  \
# count       4424.000000        4424.000000  4424.000000
# mean           5.886980           1.727396     8.899186
# std            5.298964           1.311632     4.331792
# min            0.000000           0.000000     0.000000
# 25%            0.000000           1.000000     5.000000
# 50%            7.000000           1.000000     9.000000
# 75%           11.000000           2.000000    12.000000
# max           17.000000           7.000000    16.000000
#
#        Daytime/evening attendance  Previous qualification  \
# count                 4424.000000             4424.000000
# mean                     0.890823                1.531420
# std                      0.311897                3.963707
# min                      0.000000                0.000000
# 25%                      1.000000                0.000000
# 50%                      1.000000                0.000000
# ...

# %%
# Identifica registros duplicados con `duplicated().sum()` y elimínalos con `drop_duplicates()`.

# Identificar duplicados
num_duplicates = df.duplicated().sum()
print(f"\nNúmero de registros duplicados antes de la eliminación: {num_duplicates}")

# Eliminar duplicados
df_cleaned = df.drop_duplicates()

print("\nDataFrame después de eliminar registros duplicados:")
print(df_cleaned.head())

print(f"\nNúmero de registros después de eliminar duplicados: {len(df_cleaned)}")
df=df_cleaned
# Out:
# Número de registros duplicados antes de la eliminación: 0
#
# DataFrame después de eliminar registros duplicados:
#    Application mode  Application order  Course  Daytime/evening attendance  \
# 0                 7                  5       1                           1
# 1                 5                  1      10                           1
# 2                 0                  5       4                           1
# 3                 7                  2      14                           1
# 4                11                  1       2                           0
#
#    Previous qualification  Previous qualification (grade)  Nacionality  \
# 0                       0                              28            0
# 1                       0                              78            0
# 2                       0                              28            0
# 3                       0                              28            0
# ...

# %%
# Aplica `boxplot` para detectar outliers en las variables numéricas

import matplotlib.pyplot as plt
plt.show()
# Aplica boxplot para detectar outliers en las variables numéricas
for col in numeric_cols:
    plt.figure(figsize=(10, 4))
    df_cleaned.boxplot(column=col)
    plt.title(f'Boxplot de {col}')
    plt.ylabel('Valor')

# %%
#  Indentifica y elimina  los valores atipicos de cada variable numerica utilizando el rango intercuartilico (IQR)

import matplotlib.pyplot as plt
# Function to remove outliers using IQR
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_cleaned = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df_cleaned

# Apply the outlier removal function to each numerical column
df_no_outliers = df.copy() # Create a copy to store the result without modifying the original df in the loop

for col in numeric_cols:
    initial_rows = len(df_no_outliers)
    df_no_outliers = remove_outliers_iqr(df_no_outliers, col)
    removed_rows = initial_rows - len(df_no_outliers)
    print(f"Se eliminaron {removed_rows} filas con valores atípicos en la columna '{col}'")

print(f"\nDataFrame después de eliminar valores atípicos: {len(df_no_outliers)} filas.")

# Update the main DataFrame reference if you want to use the dataframe without outliers
df = df_no_outliers

print("\nDataFrame después de la eliminación de valores atípicos por IQR:")
print(df.head())

print(f"\nEl dataframe tiene {len(df)} filas después de eliminar outliers.")

# Optional: Re-plot boxplots to see the effect of outlier removal
# for col in numeric_cols:
#     plt.figure(figsize=(10, 4))
#     df.boxplot(column=col)
#     plt.title(f'Boxplot de {col} después de eliminar outliers')
#     plt.ylabel('Valor')
# plt.show()
# Out:
# Se eliminaron 441 filas con valores atípicos en la columna 'Age at enrollment'
# Se eliminaron 467 filas con valores atípicos en la columna 'Curricular units 1st sem (credited)'
# Se eliminaron 456 filas con valores atípicos en la columna 'Curricular units 1st sem (enrolled)'
# Se eliminaron 19 filas con valores atípicos en la columna 'Curricular units 1st sem (evaluations)'
# Se eliminaron 0 filas con valores atípicos en la columna 'Curricular units 1st sem (approved)'
# Se eliminaron 416 filas con valores atípicos en la columna 'Curricular units 1st sem (grade)'
# Se eliminaron 127 filas con valores atípicos en la columna 'Curricular units 1st sem (without evaluations)'
# Se eliminaron 13 filas con valores atípicos en la columna 'Curricular units 2nd sem (credited)'
# Se eliminaron 1071 filas con valores atípicos en la columna 'Curricular units 2nd sem (enrolled)'
# Se eliminaron 20 filas con valores atípicos en la columna 'Curricular units 2nd sem (evaluations)'
# ...

# %%
# prompt: generam un grafico ded barras de cuantos registros hay por clase defineme cual es el drop, current ando graduate

import matplotlib.pyplot as plt
# Generar el gráfico de barras para la distribución de 'Target'
plt.figure(figsize=(8, 6))
df['Target'].value_counts().plot(kind='bar', color=['skyblue', 'lightgreen', 'salmon'])
plt.title('Distribución de Registros por Clase (Target)')
plt.xlabel('Clase')
plt.ylabel('Número de Registros')
plt.xticks(ticks=[0, 1, 2], labels=['Drop', 'Graduate', 'Enrolled'], rotation=0) # Asumiendo 0=Drop, 1=Graduate, 2=Enrolled
plt.show()

# %%
#  cuantos datos tiene el df

print(f"\nEl dataframe tiene {len(df)} filas y {len(df.columns)} columnas.")
print(f"\nEl dataframe limpio (sin duplicados y sin valores atípicos) tiene {len(df_no_outliers)} filas y {len(df_no_outliers.columns)} columnas.")
# Out:
# El dataframe tiene 1304 filas y 36 columnas.
#
# El dataframe limpio (sin duplicados y sin valores atípicos) tiene 1304 filas y 36 columnas.

# %%
# prompt: puedes generame una grafica con la cantidad de datos antes de hacer la eliminacion de duplicados, atipicos y nulos y despues de hacer la eliminacion, damelo en porcentajes

import pandas as pd
import matplotlib.pyplot as plt
# Obtener la cantidad de datos antes y después de la limpieza
count_before = len(df_cleaned) # Después de eliminar duplicados
count_after = len(df_no_outliers) # Después de eliminar duplicados y atípicos

# Calcular la cantidad de datos eliminados
count_removed = count_before - count_after

# Calcular porcentajes
total_original = len(pd.read_csv('DATASTUDENTS.csv', sep=";")) # Volvemos a leer para el total original
percentage_kept = (count_after / total_original) * 100
percentage_removed = (count_removed / total_original) * 100

# Datos para la gráfica
labels = ['Datos Retenidos', 'Datos Eliminados']
sizes = [percentage_kept, percentage_removed]
colors = ['#66c2a5', '#fc8d62'] # Colores amigables

# Crear la gráfica de pastel
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Porcentaje de Datos Retenidos vs. Eliminados', fontsize=14)
plt.axis('equal')  # Asegura que el pastel sea un círculo
plt.show()

print(f"\nCantidad original de registros: {total_original}")
print(f"Cantidad de registros después de eliminar duplicados: {count_before}")
print(f"Cantidad de registros después de eliminar duplicados y valores atípicos: {count_after}")
print(f"Cantidad de registros eliminados (duplicados, nulos y atípicos): {count_removed}")
print(f"Porcentaje de datos retenidos: {percentage_kept:.2f}%")
print(f"Porcentaje de datos eliminados: {percentage_removed:.2f}%")
# Out:
# Cantidad original de registros: 4424
# Cantidad de registros después de eliminar duplicados: 4424
# Cantidad de registros después de eliminar duplicados y valores atípicos: 1304
# Cantidad de registros eliminados (duplicados, nulos y atípicos): 3120
# Porcentaje de datos retenidos: 29.48%
# Porcentaje de datos eliminados: 70.52%

# %%
#  Realiza histogramas  por clase por cada columna numérica separada por clases (super puestas), verifique columnas numericas del dataframe, la columna de clase es "Result", el eje y que sea la frecuencia, por cada clase muestra en el grafico la media y mediana, excluya las categoricas

import matplotlib.pyplot as plt
# Histograms for numerical columns by 'Result' class

# Ensure 'Result' is in the categorical columns and is encoded
if 'Target' in numeric_cols:
    numeric_cols.remove('Target')
    if 'Target' not in categorical_cols:
        categorical_cols.append('Target') # Ensure 'Result' is treated as categorical

# Apply LabelEncoder to 'Result' if it's not already encoded
if df['Target'].dtype not in ['int64', 'float64']:
    label_encoder = LabelEncoder()
    df['Target'] = label_encoder.fit_transform(df['Target'])
    print("\n'Target' column encoded.")
    print(df[['Target']].head())


# Get unique classes in the 'Result' column
classes = df['Target'].unique()
classes.sort() # Sort classes for consistent plotting order

# Iterate through each numerical column
for col in numeric_cols:
    plt.figure(figsize=(12, 6))
    plt.title(f'Histogram of {col} by Result Class')
    plt.xlabel(col)
    plt.ylabel('Frequency')

    # Iterate through each class in the 'Result' column
    for cls in classes:
        # Filter data for the current class
        df_class = df[df['Target'] == cls]

        # Plot histogram for the current class
        # Set alpha for transparency to see overlapping histograms
        plt.hist(df_class[col], bins=30, alpha=0.5, label=f'Class {cls}')

        # Calculate mean and median for the current class
        mean_val = df_class[col].mean()
        median_val = df_class[col].median()

        # Add vertical lines for mean and median
        plt.axvline(mean_val, color=plt.cm.get_cmap('viridis')(cls/len(classes)), linestyle='dashed', linewidth=1, label=f'Class {cls} Mean: {mean_val:.2f}')
        plt.axvline(median_val, color=plt.cm.get_cmap('viridis')(cls/len(classes)), linestyle='dotted', linewidth=1, label=f'Class {cls} Median: {median_val:.2f}')


    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.show()
# Out:
# /tmp/ipython-input-17-2541077348.py:45: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   plt.axvline(mean_val, color=plt.cm.get_cmap('viridis')(cls/len(classes)), linestyle='dashed', linewidth=1, label=f'Class {cls} Mean: {mean_val:.2f}')
# /tmp/ipython-input-17-2541077348.py:46: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   plt.axvline(median_val, color=plt.cm.get_cmap('viridis')(cls/len(classes)), linestyle='dotted', linewidth=1, label=f'Class {cls} Median: {median_val:.2f}')

# %%
# Usa `pairplot()` para explorar visualmente las relaciones entre pares de variables numéricas, separadas por clase objetivo. La clase objetivo es "Target"
# Si son mas de 3 columnas numéricas grafique nada mas con las primeras 5 con mayor correlación y las 3 con menor correlación

import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the correlation matrix for numerical columns
correlation_matrix = df[numeric_cols + ['Target']].corr()

# Get correlations with the target variable
target_correlation = correlation_matrix['Target'].sort_values(ascending=False)

# Drop the correlation of 'Target' with itself
target_correlation = target_correlation.drop('Target')

# Get the top 5 columns with the highest positive correlation and bottom 3 with lowest (most negative) correlation
# Ensure we have enough columns before slicing
num_cols_to_consider = len(numeric_cols)

if num_cols_to_consider > 5:
    # Get top 5 and bottom 3 correlated columns
    top_correlated_cols = target_correlation.head(5).index.tolist()
    bottom_correlated_cols = target_correlation.tail(min(3, num_cols_to_consider - 5)).index.tolist() # Ensure we don't take more than available

    # Combine the selected columns, ensuring uniqueness
    selected_cols = list(set(top_correlated_cols + bottom_correlated_cols + ['Target']))
else:
    # If 5 or fewer numerical columns, just use all numerical columns + Target
    selected_cols = numeric_cols + ['Target']

print("\nColumnas seleccionadas para el pairplot (Top 5 y Bottom 3 correlacionadas con 'Target'):")
print(selected_cols)

# Create the pairplot using the selected columns and hue by 'Target'
# Use a subset of the data if it's too large to avoid memory issues or long computation times
# For large datasets, consider sampling or using a subset of variables
try:
    if len(df) > 10000: # Example threshold, adjust as needed
        print("\nEl DataFrame es grande. Usando una muestra aleatoria para el pairplot.")
        df_subset = df[selected_cols].sample(n=10000, random_state=42) # Sample 10000 rows
        sns.pairplot(df_subset, hue='Target')
    else:
        sns.pairplot(df[selected_cols], hue='Target')
    plt.suptitle('Pairplot de Variables Numéricas Seleccionadas Separadas por Clase Objetivo (Target)', y=1.02)
    plt.show()
except Exception as e:
    print(f"Error al generar el pairplot: {e}")
    print("Asegúrate de que las columnas seleccionadas existen y son numéricas (excluyendo el hue).")
# Out:
# Columnas seleccionadas para el pairplot (Top 5 y Bottom 3 correlacionadas con 'Target'):
# ['Curricular units 1st sem (enrolled)', 'Curricular units 2nd sem (grade)', 'Curricular units 1st sem (approved)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (without evaluations)', 'Curricular units 1st sem (grade)', 'Curricular units 2nd sem (approved)', 'Curricular units 2nd sem (enrolled)', 'Target']

# %%
# Usa `corr()` para obtener la matriz de correlación de las variables numéricas y `heatmap()` para visualizarla. No incluya la variable objetivo

import matplotlib.pyplot as plt
# Obtener la matriz de correlación de las variables numéricas (excluyendo la variable objetivo)
correlation_matrix_numeric = df[numeric_cols].corr()

# Visualizar la matriz de correlación con un heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix_numeric, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Matriz de Correlación de Variables Numéricas (Excluyendo Target)')
plt.show()

# %%
# Aplique chi cuadrado sobre las variables categóricas teniendo en cuenta que la variable objetivo es “Target”. Brinde el reporte de que variables son significativas y cuales no

import pandas as pd
from scipy.stats import chi2_contingency

# Variables categóricas (excluyendo la variable objetivo 'Target' de las variables predictoras)
categorical_predictors = [col for col in categorical_cols if col != 'Target']

# Variable objetivo
target_variable = 'Target'

print(f"\nRealizando prueba de Chi-cuadrado para variables categóricas vs '{target_variable}':")

significant_vars = []
insignificant_vars = []
alpha = 0.05 # Nivel de significancia

for col in categorical_predictors:
    print(f"\nAnalizando variable: {col}")
    # Crear la tabla de contingencia
    contingency_table = pd.crosstab(df[col], df[target_variable])
    print("Tabla de Contingencia:")
    print(contingency_table)

    # Realizar la prueba de chi-cuadrado
    chi2, p, dof, expected = chi2_contingency(contingency_table)

    print(f"Estadístico Chi-cuadrado: {chi2:.4f}")
    print(f"Valor p: {p:.4f}")
    print(f"Grados de libertad: {dof}")
    # print("Frecuencias esperadas:")
    # print(expected)

    # Determinar si la variable es significativa
    if p < alpha:
        print(f"El valor p ({p:.4f}) es menor que alpha ({alpha}). La variable '{col}' es ESTADÍSTICAMENTE SIGNIFICATIVA.")
        significant_vars.append(col)
    else:
        print(f"El valor p ({p:.4f}) es mayor o igual que alpha ({alpha}). La variable '{col}' NO es ESTADÍSTICAMENTE SIGNIFICATIVA.")
        insignificant_vars.append(col)

print("\n--- Reporte de Significación ---")
print(f"\nVariables Categóricas Significativas (p < {alpha}):")
if significant_vars:
    for var in significant_vars:
        print(f"- {var}")
else:
    print("No hay variables categóricas significativas al nivel alpha especificado.")

print(f"\nVariables Categóricas No Significativas (p >= {alpha}):")
if insignificant_vars:
    for var in insignificant_vars:
        print(f"- {var}")
else:
    print("Todas las variables categóricas analizadas son significativas.")
# Out:
# Realizando prueba de Chi-cuadrado para variables categóricas vs 'Target':
#
# Analizando variable: Gender
# Tabla de Contingencia:
# Target    0    1    2
# Gender
# 0       155  148  644
# 1        75   78  204
# Estadístico Chi-cuadrado: 13.6574
# Valor p: 0.0011
# Grados de libertad: 2
# El valor p (0.0011) es menor que alpha (0.05). La variable 'Gender' es ESTADÍSTICAMENTE SIGNIFICATIVA.
#
# Analizando variable: Daytime/evening attendance
# Tabla de Contingencia:
# Target                        0    1    2
# Daytime/evening attendance
# 0                             7    4   42
# 1                           223  222  806
# Estadístico Chi-cuadrado: 5.3828
# Valor p: 0.0678
# Grados de libertad: 2
# El valor p (0.0678) es mayor o igual que alpha (0.05). La variable 'Daytime/evening attendance' NO es ESTADÍSTICAMENTE SIGNIFICATIVA.
#
# Analizando variable: Displaced
# Tabla de Contingencia:
# Target       0    1    2
# Displaced
# 0           75   84  300
# ...

# %%
# Para este proceso solo tome las características numéricas halladas anteriormente. Si la columna "Result" tiene solo 2 valores aplique t-student sino aplique anova, y determine qué características  son significativas y cuáles no

import pandas as pd
from scipy import stats

print("\nRealizando pruebas estadísticas (t-student o ANOVA) para Variables Numéricas vs. Target:")
print("-" * 80)

# Nivel de significancia (alpha)
alpha = 0.05

# Asegurarse de que 'Result' está presente y es numérica para este análisis
if 'Target' in df.columns and pd.api.types.is_numeric_dtype(df['Target']):
    # Obtener las clases únicas de 'Result'
    result_classes = df['Target'].unique()
    num_classes = len(result_classes)

    # Iterar sobre cada variable numérica
    for col in numeric_cols:
        print(f"Analizando la relación entre '{col}' y 'Target' ({num_classes} clases)...")

        # Crear una lista de series, una por cada grupo de 'Result'
        groups = [df[col][df['Target'] == cls].dropna() for cls in result_classes]

        # Verificar si los grupos tienen suficientes datos
        valid_groups = [group for group in groups if len(group) > 1]

        if len(valid_groups) == num_classes: # Solo procedemos si todos los grupos tienen datos > 1
            if num_classes == 2:
                # Aplicar T-student si hay exactamente 2 clases en 'Result'
                print(f"  Aplicando prueba t-student (2 clases en 'Target')...")
                try:
                    # Realizar el test t-student independiente
                    # asume varianzas iguales; para asumir desiguales use equal_var=False
                    t_statistic, p_value = stats.ttest_ind(valid_groups[0], valid_groups[1], nan_policy='omit')

                    print(f"  Estadístico T: {t_statistic:.4f}")
                    print(f"  Valor p: {p_value:.4f}")

                    # Determinar significancia
                    if p_value < alpha:
                        print(f"  Conclusión: '{col}' es SIGNIFICATIVA (p < {alpha}) - Hay una diferencia promedio estadísticamente significativa entre los grupos de 'Target'.")
                    else:
                        print(f"  Conclusión: '{col}' NO es SIGNIFICATIVA (p >= {alpha}) - No hay evidencia suficiente de diferencia promedio entre los grupos de 'Target'.")

                except Exception as e:
                    print(f"  Error al realizar la prueba t-student para '{col}': {e}")

            elif num_classes > 2:
                # Aplicar ANOVA si hay más de 2 clases en 'Result'
                print(f"  Aplicando prueba ANOVA ({num_classes} clases en 'Target')...")
                try:
                    # Realizar el test ANOVA
                    f_statistic, p_value = stats.f_oneway(*valid_groups)

                    print(f"  Estadístico F: {f_statistic:.4f}")
                    print(f"  Valor p: {p_value:.4f}")

                    # Determinar significancia
                    if p_value < alpha:
                        print(f"  Conclusión: '{col}' es SIGNIFICATIVA (p < {alpha}) - Hay al menos un grupo de 'Result' cuya media difiere significativamente de las otras.")
                    else:
                        print(f"  Conclusión: '{col}' NO es SIGNIFICATIVA (p >= {alpha}) - No hay evidencia suficiente de que las medias de los grupos de 'Result' difieran.")

                except Exception as e:
                     print(f"  Error al realizar la prueba ANOVA para '{col}': {e}")

            else:
                print(f"  No se puede realizar la prueba estadística para '{col}': El número de clases de 'Target' ({num_classes}) no es 2 o más de 2.")
        else:
             print(f"  No se puede realizar la prueba estadística para '{col}': No hay suficientes datos en algunos grupos de 'Target'.")


        print("-" * 80)

else:
    print("Error: La columna 'Target' no está presente o no está en un formato numérico adecuado para realizar pruebas t-student o ANOVA.")
    print("Asegúrate de que 'Target' fue codificada numéricamente.")

# Reporte final de variables numéricas significativas y no significativas (basado en las pruebas realizadas)
print("\nReporte de Significancia para Variables Numéricas (Nivel alpha = 0.05):")
print("-" * 60)

significant_numeric_vars = []
non_significant_numeric_vars = []
untested_numeric_vars = []

# Re-iterar o almacenar los resultados para el reporte final si se desea
# Este snippet solo imprime durante la ejecución. Para un reporte consolidado,
# se deberían almacenar los resultados de p_value en un diccionario o lista.

# Ejemplo de cómo podrías estructurarlo (requiere modificar el bucle anterior para almacenar):
# numeric_test_results = {} # Diccionario para almacenar p-values de tests numéricos

# Después del bucle de t-student/ANOVA:
# print("Variables Numéricas Significativas (asociación con 'Result'):")
# sig_num = [var for var, p in numeric_test_results.items() if p < alpha]
# if sig_num:
#     for var in sig_num:
#         print(f"- {var} (Valor p: {numeric_test_results[var]:.4f})")
# else:
#     print("Ninguna variable numérica fue estadísticamente significativa.")

# print("\nVariables Numéricas NO Significativas (sin asociación con 'Result'):")
# non_sig_num = [var for var, p in numeric_test_results.items() if p >= alpha]
# if non_sig_num:
#      print("Variables testeadas como no significativas:")
#      for var in non_sig_num:
#         print(f"- {var} (Valor p: {numeric_test_results[var]:.4f})")
# else:
#     print("Todas las variables numéricas testeadas fueron estadísticamente significativas.")

# print("\nVariables Numéricas NO testeadas (por falta de datos en grupos, etc.):")
# # Aquí necesitarías una lista de variables que no pudieron ser testeadas
# # untested_num = ...
# if untested_numeric_vars:
#      for var in untested_numeric_vars:
#           print(f"- {var}")
# else:
#      print("Todas las variables numéricas fueron testeadas.")


# Como el código anterior no almacena los resultados centralmente,
# simplemente resumimos lo que se imprimió:
print("Consulta los resultados detallados de cada variable numérica y su valor p en la salida anterior.")
print("Las variables con un 'Valor p' menor a 0.05 se consideran significativas.")

print("-" * 60)
# Out:
# Realizando pruebas estadísticas (t-student o ANOVA) para Variables Numéricas vs. Target:
# --------------------------------------------------------------------------------
# Analizando la relación entre 'Age at enrollment' y 'Target' (3 clases)...
#   Aplicando prueba ANOVA (3 clases en 'Target')...
#   Estadístico F: 5.2634
#   Valor p: 0.0053
#   Conclusión: 'Age at enrollment' es SIGNIFICATIVA (p < 0.05) - Hay al menos un grupo de 'Result' cuya media difiere significativamente de las otras.
# --------------------------------------------------------------------------------
# Analizando la relación entre 'Curricular units 1st sem (credited)' y 'Target' (3 clases)...
#   Aplicando prueba ANOVA (3 clases en 'Target')...
#   Estadístico F: nan
#   Valor p: nan
#   Conclusión: 'Curricular units 1st sem (credited)' NO es SIGNIFICATIVA (p >= 0.05) - No hay evidencia suficiente de que las medias de los grupos de 'Result' difieran.
# ...

# %%
 # almacenar el dataframe que tengo hasta el momento en un csv, y una lista con el nombre de las variables numéricas y de las categóricas

# Guardar el DataFrame final en un archivo CSV
df.to_csv('dataframe_final.csv', index=False,sep=";")

# Guardar las listas de variables numéricas y categóricas
import json

variables_info = {
    'numeric_variables': numeric_cols,
    'categorical_variables': categorical_cols
}

with open('variables_info.json', 'w') as f:
    json.dump(variables_info, f, indent=4)

print("\nDataFrame final guardado como 'dataframe_final.csv'")
print("Listas de variables numéricas y categóricas guardadas como 'variables_info.json'")
# Out:
# DataFrame final guardado como 'dataframe_final.csv'
# Listas de variables numéricas y categóricas guardadas como 'variables_info.json'
